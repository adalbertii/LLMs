# %% [markdown]
# <a href="https://colab.research.google.com/github/adalbertii/LLMs/blob/main/qdrant_FastEmbed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 55.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 42.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 31.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !pip install qdrant-client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.6/306.6 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 40.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 20.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.6
#     Uninstalling protobuf-4.25.6:
#       Successfully uninstalled protobuf-4.25.6
# ...

# %%
from sentence_transformers import SentenceTransformer
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams
import time

# %%
import os

# %%
os.environ['QDRANT_HOST'] = 'https://dfb4afdf-7ab5-4f26-aea3-4e577dcf84a6.europe-west3-0.gcp.cloud.qdrant.io:6333'
os.environ['QDRANT_API_KEY'] = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc3MiOiJtIn0.BBGLBPO7rDAzjJJNl3TXgahEpJ8QjF6NS_yjQPpiWZI'

# %%
client = QdrantClient(os.getenv('QDRANT_HOST'), api_key=os.getenv('QDRANT_API_KEY'))

# %%
# Load a sentence transformer model
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# ...

# %%
# Sample dataset
sentences = ["This is a sample sentence.", "Embeddings are useful.", "Sentence for the embedding"] # Add more sentences

# %%
# Generate embeddings
start_time = time.time()
embeddings = model.encode(sentences)
end_time = time.time()
print("Time taken to generate embeddings:", end_time - start_time, "seconds")
# Out:
# Time taken to generate embeddings: 0.298642635345459 seconds

# %%
size_vector = len(embeddings[0])
print(size_vector)
# Out:
# 384

# %%
vector_param = VectorParams(size=len(embeddings[0]), distance=Distance.DOT)
client.create_collection(collection_name="wmi-01", vectors_config= vector_param)
client.upload_collection(collection_name="wmi-01", vectors=embeddings)

# %%
quer_sentence = ["This is aa sampleee sentence."]
quer_emb = model.encode(quer_sentence)

# %%
# Perform a search query
#query_vector = embeddings[0] # using the first sentence embedding as a query
#search_results = client.search(collection_name="wmi-01", query_vector=quer_emb[0])
search_results = client.query_points(
    collection_name="wmi-01",
    query=quer_emb[0],
    with_payload=False,
    limit=3
).points

# search_results = client.query_points(collection_name="wmi-01", query_vector=quer_emb[0])
print(search_results)
# Out:
# [ScoredPoint(id='40d559bd-9655-4a03-bd4b-5c3678342fe0', version=0, score=0.73979783, payload=None, vector=None, shard_key=None, order_value=None), ScoredPoint(id='4f1ec041-949a-45ff-99db-edfb5fd6a87e', version=0, score=0.37397084, payload=None, vector=None, shard_key=None, order_value=None), ScoredPoint(id='4c7e5f5b-9e4e-42a3-b10a-abb0e6e8c89b', version=0, score=0.130065, payload=None, vector=None, shard_key=None, order_value=None)]

# %%
quer_sentence = ["This is a samplee sentence."]
quer_emb = model.encode(quer_sentence)

# %%
search_results = client.query_points(
    collection_name="wmi-01",
    query=quer_emb[0],
    with_payload=False,
    limit=1
).points

# search_results = client.query_points(collection_name="wmi-01", query_vector=quer_emb[0])
scored_p = search_results[0]
print(scored_p.payload)
#print(search_results.ScoredPoint.payload)
# Out:
# None

# %%
# !pip install fastembed
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 67.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.8/324.8 kB 17.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.6 MB/s eta 0:00:00
# ...

# %%
from fastembed.embedding import DefaultEmbedding
# Out:
# 2025-03-04 12:34:31.050 | WARNING  | fastembed.embedding:<module>:7 - DefaultEmbedding, FlagEmbedding, JinaEmbedding are deprecated.Use from fastembed import TextEmbedding instead.

# %%
# Load a FastEmbed model
fastembed_model = DefaultEmbedding()
# Same dataset as the first benchmark
sentences = ["This is a sample sentence.", "Embeddings are useful."] # more sentences
# Generate embeddings with FastEmbed
start_time = time.time()
fast_embeddings = fastembed_model.embed(sentences)
end_time = time.time()
# Out:
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# model_optimized.onnx:   0%|          | 0.00/66.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.24k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/706 [00:00<?, ?B/s]

# %%
# !pip install -U sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 857.1 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
from sentence_transformers import SentenceTransformer

#model = SentenceTransformer('sdadas/st-polish-paraphrase-from-distilroberta')
# https://huggingface.co/sdadas/st-polish-paraphrase-from-distilroberta


model = SentenceTransformer('sdadas/mmlw-retrieval-roberta-base')
#https://huggingface.co/collections/sdadas/polish-embedding-models-66e69fe67240b605c9348ea7
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/127 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.65k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/862 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/249M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.44k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.36M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/75.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
sentences = ["Warszawa", "Wrocław", "Poznań", "Gdańsk"]
embeddings = model.encode(sentences)
print(embeddings)
# Out:
# [[-0.03703077 -0.1892262   0.20826152 ... -0.28987858 -0.03390881
#    0.30218735]
#  [-0.13333023 -0.24806556  0.12532635 ...  0.10975796  0.4170849
#    0.29690254]
#  [-0.08295472 -0.51896614  0.10577822 ...  0.01893851  0.5510895
#    0.23933639]
#  [-0.25852844 -0.60837543  0.5986511  ... -0.3336973  -0.4879416
#    0.3874399 ]]

# %%
size_vector = len(embeddings[0])
print(size_vector)
# Out:
# 768

# %%
vector_param = VectorParams(size=len(embeddings[0]), distance=Distance.DOT)
client.create_collection(collection_name="wmi-03", vectors_config= vector_param)
# Out:
# True

# %%
pay =  [{"miasto": "Warszawa"},
        {"miasto": "Wrocław"},
        {"miasto": "Poznań"},
        {"miasto": "Gdańsk"}
        ]

# %%
client.upload_collection(collection_name="wmi-03", vectors=embeddings, payload=pay )
client.upload_collection

quer_sentence = ["Waarsawa"]
quer_emb = model.encode(quer_sentence)

# %%
search_results = client.query_points(
    collection_name="wmi-03",
    query=quer_emb[0],
    with_payload=True,
    limit=1
).points

# search_results = client.query_points(collection_name="wmi-01", query_vector=quer_emb[0])
scored_p = search_results[0]
print(scored_p.payload)
#print(search_results.ScoredPoint.payload)
# Out:
# {'miasto': 'Warszawa'}
