# %% [markdown]
# <a href="https://colab.research.google.com/github/adalbertii/LLMs/blob/main/dataset_miejscowosci.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Odczytanie pliku CSV
plik_wejsciowy = 'miejscowosci.csv'
df = pd.read_csv(plik_wejsciowy)

# Sprawdzenie, czy istnieje kolumna 'nazwa'
if 'NAZWA' in df.columns:
    # Utworzenie listy niepowtarzalnych miejscowości
    unikalne_miejscowosci = df['NAZWA'].unique()

    # Konwersja do DataFrame
    df_wyniki = pd.DataFrame(unikalne_miejscowosci, columns=['nazwa'])

    # Zapisanie do pliku 'wyniki.csv'
    df_wyniki.to_csv('wyniki.csv', index=False)
    print("Zapisano niepowtarzalne miejscowości do pliku wyniki.csv")
else:
    print("Brak kolumny 'nazwa' w pliku wejściowym.")
# Out:
# Zapisano niepowtarzalne miejscowości do pliku wyniki.csv

# %%
df_wyniki[:10]
# Out:
#                    nazwa
# 0               Adaminów
# 1                 Adamka
# 2                 Adamów
# 3               Adamówka
# 4                Adamowo
# 5          Adamowo-Dozin
# 6               Adolfowo
# 7            Agnieszkowo
# 8  Agnieszkowo-Krzyżówki
# 9            Aleksandrów

# %%
df_wyniki.shape
# Out:
# (3292, 1)

# %%
# !pip install datasets
from datasets import load_dataset
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 15.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...

# %%
dataset = load_dataset(
    'text',
    data_files='wyniki.csv',
    split='train',
)

print(dataset)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset({
#     features: ['text'],
#     num_rows: 3293
# })

# %%
dataset_full = dataset.train_test_split(shuffle=True, test_size=0.2)

# %%
dataset_train, dataset_valid = dataset_full['train'], dataset_full['test']
print(dataset_train)
print(dataset_valid)
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 2634
# })
# Dataset({
#     features: ['text'],
#     num_rows: 659
# })
