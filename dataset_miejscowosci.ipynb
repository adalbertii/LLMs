# %% [markdown]
# <a href="https://colab.research.google.com/github/adalbertii/LLMs/blob/main/dataset_miejscowosci.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Odczytanie pliku CSV
plik_wejsciowy = 'miejscowosci.csv'
df = pd.read_csv(plik_wejsciowy)

# Sprawdzenie, czy istnieje kolumna 'nazwa'
if 'NAZWA' in df.columns:
    # Utworzenie listy niepowtarzalnych miejscowości
    unikalne_miejscowosci = df['NAZWA'].unique()

    # Konwersja do DataFrame
    df_wyniki = pd.DataFrame(unikalne_miejscowosci, columns=['nazwa'])

    # Zapisanie do pliku 'wyniki.csv'
    df_wyniki.to_csv('miejscowosci-distinct.csv', index=False)
    print("Zapisano niepowtarzalne miejscowości do pliku wyniki.csv")
else:
    print("Brak kolumny 'nazwa' w pliku wejściowym.")
# Out:
# Zapisano niepowtarzalne miejscowości do pliku wyniki.csv

# %%
df_wyniki[:10]
# Out:
#                    nazwa
# 0               Adaminów
# 1                 Adamka
# 2                 Adamów
# 3               Adamówka
# 4                Adamowo
# 5          Adamowo-Dozin
# 6               Adolfowo
# 7            Agnieszkowo
# 8  Agnieszkowo-Krzyżówki
# 9            Aleksandrów

# %%
df_wyniki.shape
# Out:
# (7604, 1)

# %%
# !pip install nlpaug
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 5.6 MB/s eta 0:00:00
# ...

# %%
import nlpaug.augmenter.char as nac

#aug = nac.KeyboardAug(name='Keyboard_Aug', aug_char_min=1, aug_char_max=1, aug_char_p=0.3, aug_word_p=0.3,
#                      aug_word_min=1, aug_word_max=10, stopwords=None, tokenizer=None, reverse_tokenizer=None,
#                      include_special_char=False, include_numeric=True, include_upper_case=True, lang='en', verbose=0,
#                      stopwords_regex=None, model_path=None, min_char=4)

aug = nac.RandomCharAug(action='substitute', name='RandomChar_Aug', aug_char_min=1, aug_char_max=2, aug_char_p=0.3,
                        aug_word_p=0.3, aug_word_min=1, aug_word_max=10, include_upper_case=True, include_lower_case=True,
                        include_numeric=True, min_char=4, swap_mode='adjacent', spec_char='[!@#$%^&*()_+', stopwords=None,
                        tokenizer=None, reverse_tokenizer=None, verbose=0, stopwords_regex=None)

# %%
import csv

# %%
with open('miejscowosci-distinct.csv', 'r', newline='') as wej, \
  open('wynik.csv', 'w', newline='') as wyj: # Zmieniono nazwę pliku wynikowego na .csv

  reader = csv.reader(wej)
  writer = csv.writer(wyj, delimiter=':')  # Ustawiamy separator na ':'

  # Odczytujemy nagłówki z pliku wejściowego
  naglowki = next(reader)

  # Dodajemy nagłówek dla nowej kolumny
  #naglowki.append('Nowa nazwa')

  # Zapisujemy nagłówki do pliku wyjściowego
  writer.writerow(naglowki)
  nn = 5
  # Przetwarzamy dane
  for row in reader:
    nazwa = row[0]  # Zakładamy, że nazwa miejscowości jest w pierwszej kolumnie (index 0)

    for _ in range(nn):
      nowa_nazwa = aug.augment(nazwa)
      writer.writerow([nazwa, str(nowa_nazwa[0])])
      #row.append(str(nowa_nazwa[0])) # Dodajemy przetworzoną nazwę do wiersza
      #writer.writerow(row)  # Zapisujemy zmodyfikowany wiersz

# %%
 if row:  # Upewniamy się, że wiersz nie jest pusty
                    nazwa_poczatkowa = row[0]  # Zakładamy, że nazwa jest w pierwszej kolumnie
                    for _ in range(n):  # Wykonujemy konwersję n razy
                        nazwa_przetworzona = konwersja(nazwa_poczatkowa)
                        writer.writerow([nazwa_poczatkowa, nazwa_przetworzona])
                        nazwa_poczatkowa = nazwa_przetworzona # kolejna iteracja

# %%
dfout = pd.read_csv('wynik.csv')
dfout[:10]
# Out:
#                nazwa
# 0  Adaminów:edamZnów
# 1  Adaminów:AZaminUw
# 2  Adaminów:Ada_inXw
# 3  Adaminów:^daminó9
# 4  Adaminów:4damSnów
# 5      Adamka:AeAmka
# 6      Adamka:A1amkI
# 7      Adamka:Ads^ka
# 8      Adamka:Ad0cka
# 9      Adamka:AJakka

# %%
dfout.shape
# Out:
# (38020, 1)

# %%
# !pip install datasets
from datasets import load_dataset
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.9/484.9 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 13.9 MB/s eta 0:00:00
# ...

# %%
dataset = load_dataset(
    'text',
    data_files='wynik.csv',
    split='train',
)

print(dataset)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset({
#     features: ['text'],
#     num_rows: 4142
# })

# %%
dataset_full = dataset.train_test_split(shuffle=True, test_size=0.2)

# %%
dataset_train, dataset_valid = dataset_full['train'], dataset_full['test']
print(dataset_train)
print(dataset_valid)
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 3313
# })
# Dataset({
#     features: ['text'],
#     num_rows: 829
# })
